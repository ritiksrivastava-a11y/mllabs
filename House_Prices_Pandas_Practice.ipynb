# %% [markdown]
# # 🏠 **Pandas Practice 2 — House Prices**
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook. Same data as the Kaggle 'House Prices: Advanced Regression Techniques' competition._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/olga0503/DATA-605/master/train.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# # 🔍 **1. Basic Exploration**
#
# ### _`.head(n)` / `.tail(n)` → first/last rows | `.shape` → (rows, cols) | `.columns` → column names | `.dtypes` → column data types_
#
# ---

# %% [markdown]
# **Q1.1 Display the first 6 rows and the last 5 rows of `df`.**

# %%
# Write your code here

# %% [markdown]
# **Q1.2 Print the shape of `df`, the total number of columns, and the list of all column names.**

# %%
# Write your code here

# %% [markdown]
# **Q1.3 Use `.info()` and `.describe()` on `df`. What does `.describe()` tell you about the `SalePrice` column — what are its minimum, maximum, and mean?**

# %%
# Write your code here

# %% [markdown]
# # 🎯 **2. Selecting Columns & Rows**
#
# ### _`df['col']` → single column (Series) | `df[['a','b']]` → multiple columns (DataFrame) | `.loc[rows, cols]` → label-based | `.iloc[rows, cols]` → position-based_
#
# ---

# %% [markdown]
# **Q2.1 Select only the `Neighborhood`, `SalePrice`, and `YearBuilt` columns and store the result in a new variable.**

# %%
# Write your code here

# %% [markdown]
# **Q2.2 Use `.loc` to get rows 10 to 20 (inclusive), showing only the `OverallQual`, `GrLivArea`, and `SalePrice` columns.**

# %%
# Write your code here

# %% [markdown]
# **Q2.3 Use `.iloc` to get the first 5 rows and the last 3 columns of `df`.**

# %%
# Write your code here

# %% [markdown]
# # 🧮 **3. Filtering / Boolean Indexing**
#
# ### _`df[df['col'] > x]` → rows matching a condition | `&` = and | `|` = or (wrap each condition in brackets)_
#
# ---

# %% [markdown]
# **Q3.1 Filter `df` to show only houses with `SalePrice` greater than 300000.**

# %%
# Write your code here

# %% [markdown]
# **Q3.2 Filter `df` to show houses in the `Neighborhood` 'CollgCr' that have at least 3 `BedroomAbvGr`.**

# %%
# Write your code here

# %% [markdown]
# **Q3.3 Filter `df` to show houses where `OverallQual` is 8 or higher AND `YearBuilt` is after 2000.**

# %%
# Write your code here

# %% [markdown]
# # ↕️ **4. Sorting**
#
# ### _`.sort_values('col')` → ascending by default | `ascending=False` → descending | pass a list to sort by multiple columns_
#
# ---

# %% [markdown]
# **Q4.1 Sort `df` by `SalePrice` in descending order and display the top 10 most expensive houses (just the `Neighborhood`, `SalePrice`, and `GrLivArea` columns).**

# %%
# Write your code here

# %% [markdown]
# **Q4.2 Sort `df` first by `Neighborhood` (ascending) and then by `SalePrice` (descending) within each neighborhood.**

# %%
# Write your code here

# %% [markdown]
# # 🧹 **5. Missing Values & Data Cleaning**
#
# ### _`.isna().sum()` → count missing values per column | `.dropna()` → remove rows/columns | `.fillna(value)` → fill missing values | Recall the rule from the ML lecture: a mostly-empty column gets dropped, a column with a few missing rows gets filled or those rows get dropped_
#
# ---

# %% [markdown]
# **Q5.1 Find how many missing values each column has, and show only the columns that have at least one missing value, sorted from most missing to least.**

# %%
# Write your code here

# %% [markdown]
# **Q5.2 Columns like `PoolQC`, `MiscFeature`, `Alley`, and `Fence` are missing in more than 80% of rows — same situation as `Cabin` in the Titanic lecture. Drop these four columns from `df`.**

# %%
# Write your code here

# %% [markdown]
# **Q5.3 The `LotFrontage` column has a few hundred missing values but is otherwise useful. Fill its missing values with the column's median (same reasoning as filling `Age` in the Titanic lecture).**

# %%
# Write your code here

# %% [markdown]
# **Q5.4 The `Electrical` column is missing in only 1 row. Drop just that row using `dropna(subset=...)`, then confirm with `.isna().sum()` that `Electrical` has zero missing values left.**

# %%
# Write your code here

# %% [markdown]
# # 🛠️ **6. Adding, Transforming & Dropping Columns**
#
# ### _`df['new'] = ...` → add/overwrite a column | `.apply(function)` → transform values | `.drop(columns=[...])` → remove columns_
#
# ---

# %% [markdown]
# **Q6.1 Create a new column `HouseAge` = `YrSold` minus `YearBuilt` (how old the house was when it was sold).**

# %%
# Write your code here

# %% [markdown]
# **Q6.2 Create a new column `TotalSF` that adds up `TotalBsmtSF`, `1stFlrSF`, and `2ndFlrSF` (total square footage of the house).**

# %%
# Write your code here

# %% [markdown]
# **Q6.3 Drop the `Id` column — it's just a row number with no predictive value, exactly like `PassengerId` in the Titanic lecture.**

# %%
# Write your code here

# %% [markdown]
# # 📊 **7. GroupBy & Aggregation**
#
# ### _`.groupby('col')` → split by group | `.mean()`, `.median()`, `.count()`, `.agg()` → aggregate within each group_
#
# ---

# %% [markdown]
# **Q7.1 Group by `Neighborhood` and find the average `SalePrice` in each neighborhood, sorted from highest to lowest.**

# %%
# Write your code here

# %% [markdown]
# **Q7.2 Group by `OverallQual` and find the median `SalePrice` and the count of houses for each quality rating.**

# %%
# Write your code here

# %% [markdown]
# **Q7.3 Group by `YrSold` and find the average `SalePrice` and average `GrLivArea` of houses sold each year.**

# %%
# Write your code here

# %% [markdown]
# # 🔢 **8. Value Counts & Unique Values**
#
# ### _`.value_counts()` → frequency of each value | `.unique()` → distinct values | `.nunique()` → count of distinct values_
#
# ---

# %% [markdown]
# **Q8.1 Use `.value_counts()` to see how many houses fall into each `MSZoning` category. Which is the most common zoning?**

# %%
# Write your code here

# %% [markdown]
# **Q8.2 Find how many unique values exist in the `Neighborhood` column, and list them all.**

# %%
# Write your code here

# %% [markdown]
# # 🧾 **9. Duplicates & Renaming**
#
# ### _`.duplicated()` → flags duplicate rows | `.drop_duplicates()` → remove them | `.rename(columns={...})` → rename columns_
#
# ---

# %% [markdown]
# **Q9.1 Check whether `df` has any fully duplicated rows. Then rename the column `YrSold` to `YearSold` and `MoSold` to `MonthSold`.**

# %%
# Write your code here

# %% [markdown]
# # 🎯 **10. Features, Target & Train/Test Split**
#
# ### _Before any model: separate features `x` from target `y`, then hide a test set before touching anything else — same pipeline order as the ML lecture: clean → split → encode._
#
# ---

# %% [markdown]
# **Q10.1 We're going to predict whether a house is "Expensive" or not — turning this into a classification problem, just like the Titanic `Survived` example. Create a new column `Expensive` = 1 if `SalePrice` is above the median `SalePrice`, else 0. Check `.value_counts()` on it — what would the baseline accuracy be if a model always guessed the majority class?**

# %%
# Write your code here

# %% [markdown]
# **Q10.2 Build `x` using only these columns: `OverallQual`, `GrLivArea`, `YearBuilt`, `TotalBsmtSF`, `FullBath`, `BedroomAbvGr`, `GarageCars`, `MSZoning`, `Neighborhood`. Build `y` as the `Expensive` column. Then split into `x_train`, `x_test`, `y_train`, `y_test` using `train_test_split` with `test_size=0.2` and `random_state=42`.**

# %%
# Write your code here

# %% [markdown]
# # 🔤 **11. Encoding & Scaling**
#
# ### _`OneHotEncoder` → turns text categories into 0/1 columns (fit on train only!) | `StandardScaler` → puts numeric columns on the same scale, important for KNN's distance calculation_
#
# ---

# %% [markdown]
# **Q11.1 `MSZoning` and `Neighborhood` are text columns — KNN can't use them as-is. Use `OneHotEncoder` (fit only on `x_train`) to convert these two columns into 0/1 columns for both train and test.**

# %%
# Write your code here

# %% [markdown]
# **Q11.2 The numeric columns are on very different scales — `GrLivArea` runs into the thousands while `OverallQual` only goes up to 10. Use `StandardScaler` (fit only on `x_train`) to scale the numeric columns for both train and test, same reasoning as scaling `Age` and `Fare` before KNN.**

# %%
# Write your code here

# %% [markdown]
# # 🤖 **12. KNN — Train, Predict & Evaluate**
#
# ### _`.fit()` → learn from training data | `.predict()` → predict on new data | `accuracy_score()` → measure performance_
#
# ---

# %% [markdown]
# **Q12.1 Combine your encoded + scaled train features into one array (`np.hstack` or `np.concatenate` work well), and do the same for test. Train a `KNeighborsClassifier` with `k=5` on the training data.**

# %%
# Write your code here

# %% [markdown]
# **Q12.2 Use the trained model to predict on the test set, and compute the accuracy using `accuracy_score`. Is it better than the baseline you calculated in Q10.1?**

# %%
# Write your code here
