# %% [markdown]
# # 🤖 **Machine Learning Practice 1**
#
# ### _Hands-on coding practice covering Lecture 15-17: the ML pipeline, scikit-learn, data cleaning, features/target, train/test split, encoding, and your first KNN model._
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# # 💻 **1. The ML Pipeline — Imports & First Look**
#
# ### _Before building any model, set up your environment and take a first look at the raw data._
#
# ---

# %% [markdown]
# #### **Q1.1 Import the libraries you will need for a basic ML pipeline: `pandas`, `numpy`, and `train_test_split` from `sklearn.model_selection`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q1.2 Print `df.shape` and `df.info()` to understand the size of the dataset and which columns you're working with.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧰 **2. scikit-learn Basics**
#
# ### _scikit-learn (`sklearn`) is the main library used to build ML models. Every model in sklearn follows the same pattern: `.fit()` to train, `.predict()` to make predictions._
#
# ---

# %% [markdown]
# #### **Q2.1 Import `sklearn` and print its version using `sklearn.__version__`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧹 **3. Data Cleaning**
#
# ### _Real-world data almost always has missing or unusable values — these must be handled before a model can be trained on it._
#
# ---

# %% [markdown]
# #### **Q3.1 Check `df` for missing values in every column using `.isnull().sum()`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q3.2 Drop the `Cabin` column entirely, fill missing `Age` values with the median age, and drop the rows where `Embarked` is missing. Save the result as `df_clean`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🎯 **4. Features and Target**
#
# ### _The Target is the column you want to predict. The Features are the columns used as input to make that prediction._
#
# ---

# %% [markdown]
# #### **Q4.1 From `df_clean`, create `X` (features) using the columns `Pclass`, `Sex`, `Age`, `Fare`, `Embarked`, and create `y` (target) using the `Survived` column.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # ✂️ **5. Train/Test/Split**
#
# ### _`train_test_split()` divides your data into a portion used for training the model and a portion kept aside to test how well it performs on unseen data._
#
# ---

# %% [markdown]
# #### **Q5.1 Split `X` and `y` into `X_train`, `X_test`, `y_train`, `y_test` using `train_test_split()`, with 80% for training and 20% for testing, and `random_state=42`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔤 **6. Encoding**
#
# ### _Machine Learning models only work with numbers, not text. Encoding converts categorical columns into numeric form._
#
# ---

# %% [markdown]
# #### **Q6.1 In `X_train` and `X_test`, encode the `Sex` column using Label Encoding (e.g. `male` = 0, `female` = 1).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q6.2 Encode the `Embarked` column using One-Hot Encoding with `pd.get_dummies()`. Apply it consistently to both `X_train` and `X_test` so they end up with the same columns.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧮 **7. KNN — First Model**
#
# ### _K-Nearest Neighbors (KNN) predicts a new point's class by looking at the 'K' closest points in the training data and taking a majority vote._
#
# ---

# %% [markdown]
# #### **Q7.1 Import `KNeighborsClassifier` from `sklearn.neighbors`, create a model with `n_neighbors=5`, and train it using `.fit(X_train, y_train)`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q7.2 Use the trained model to predict on `X_test` using `.predict()`, then check the accuracy using `accuracy_score()` from `sklearn.metrics`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔥 **8. Challenge Questions**
#
# ### _These combine everything from this notebook — cleaning, encoding, splitting, and training — into a single end-to-end workflow._
#
# ---

# %% [markdown]
# #### **C1. Starting from the raw `df`, write a single end-to-end pipeline in one cell: clean the data, build `X` and `y`, encode categorical columns, split into train/test, train a KNN model, and print the final accuracy.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **C2. Try `n_neighbors = 3`, `7`, and `11` for your KNN model. Print the accuracy for each value. Which value gives the best accuracy on your test split?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **C3. From `df_clean`, keep only passengers older than 12 years. Rebuild the entire pipeline — features, split, encoding, training — using only this subset, and compare its accuracy to your full-dataset model from C1.**
#
# ---

# %%
# Write your code here
