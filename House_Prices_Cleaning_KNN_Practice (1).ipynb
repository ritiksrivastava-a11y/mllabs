# %% [markdown]
# # 🏠 **Pandas + Cleaning + KNN Practice — House Prices**
#
# ### _You've already covered DataFrame basics, `.loc`/`.iloc`, filtering, missing values, duplicates, and GroupBy in earlier sessions — so this notebook only reviews those briefly, then goes deep on **data cleaning** and your **first full KNN model**._
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook. Same data as the Kaggle 'House Prices: Advanced Regression Techniques' competition._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/olga0503/DATA-605/master/train.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# # 🔍 **1. Quick Pandas Warm-Up** _(fast recap — you've already covered this in detail)_
#
# ### _`.shape`, `.loc`/`.iloc`, filtering, `.sort_values()`, `.groupby()`_
#
# ---

# %% [markdown]
# **Q1.1 Print the shape of `df`, the first 5 rows, and the full list of column names.**

# %%
# Write your code here

# %% [markdown]
# **Q1.2 Use `.loc` to select the `OverallQual`, `GrLivArea`, and `SalePrice` columns for rows 20 to 30 (inclusive).**

# %%
# Write your code here

# %% [markdown]
# **Q1.3 Filter `df` to show houses where `OverallQual` is 8 or higher AND `SalePrice` is greater than 300000.**

# %%
# Write your code here

# %% [markdown]
# **Q1.4 Sort `df` by `SalePrice` in descending order and show the top 5 rows' `Neighborhood` and `SalePrice`.**

# %%
# Write your code here

# %% [markdown]
# **Q1.5 Group by `Neighborhood`, find the average `SalePrice` for each, sorted descending, and show the top 5 most expensive neighborhoods.**

# %%
# Write your code here

# %% [markdown]
# # 🧹 **2. Data Cleaning — Missing Values**
#
# ### _This is the real focus today. `.isnull().sum()` → count missing values | `.dropna()` → remove rows/columns | `.fillna(value)` → fill missing values_
#
# ---

# %% [markdown]
# **Q2.1 Use `.isnull().sum()` to find missing values per column. Show only the columns with at least one missing value, sorted from most missing to least.**

# %%
# Write your code here

# %% [markdown]
# **Q2.2 Calculate the percentage of missing values for each column (missing count ÷ total rows × 100). Drop every column where more than 80% of the values are missing (e.g. `PoolQC`, `MiscFeature`, `Alley`, `Fence`).**

# %%
# Write your code here

# %% [markdown]
# **Q2.3 `LotFrontage` has a few hundred missing values but is otherwise a useful numeric column. Fill its missing values with the column's median.**

# %%
# Write your code here

# %% [markdown]
# **Q2.4 For columns like `GarageType`, `GarageFinish`, `BsmtQual`, and `BsmtExposure`, a missing value doesn't mean "unknown" — it means the house simply has no garage / no basement. Fill these columns' missing values with the string `"None"` instead of dropping them.**

# %%
# Write your code here

# %% [markdown]
# **Q2.5 The `Electrical` column is missing in only 1 row — that's too few to fill, so just drop that row using `dropna(subset=...)`. Confirm afterwards with `.isnull().sum()` that `Electrical` has zero missing values left.**

# %%
# Write your code here

# %% [markdown]
# # 🧾 **3. Duplicates & Data Types**
#
# ### _`.duplicated()` → flags duplicate rows | `.dtypes.value_counts()` → count of numeric vs text columns_
#
# ---

# %% [markdown]
# **Q3.1 Check how many fully duplicated rows exist in `df` using `.duplicated().sum()`.**

# %%
# Write your code here

# %% [markdown]
# **Q3.2 Use `.dtypes.value_counts()` to see how many numeric columns and how many text (`object`) columns `df` has after all the cleaning above.**

# %%
# Write your code here

# %% [markdown]
# # 🛠️ **4. Feature Engineering**
#
# ### _Create new columns that combine existing information into something more useful for a model._
#
# ---

# %% [markdown]
# **Q4.1 Create a new column `HouseAge` = `YrSold` minus `YearBuilt` (how old the house was when it was sold).**

# %%
# Write your code here

# %% [markdown]
# **Q4.2 Create a new column `TotalSF` that adds up `TotalBsmtSF`, `1stFlrSF`, and `2ndFlrSF` (total square footage of the house).**

# %%
# Write your code here

# %% [markdown]
# **Q4.3 Create a new column `TotalBath` = `FullBath` + 0.5×`HalfBath` + `BsmtFullBath` + 0.5×`BsmtHalfBath`.**

# %%
# Write your code here

# %% [markdown]
# # 🎯 **5. Features, Target & Train/Test Split**
#
# ### _Separate `x` (features) from `y` (target), then hide a test set before touching anything else — same pipeline order as the ML lecture: clean → split → encode._
#
# ---

# %% [markdown]
# **Q5.1 We're going to predict whether a house is "Expensive" or not — turning this into a classification problem, just like the Titanic `Survived` example. Create a new column `Expensive` = 1 if `SalePrice` is above the median `SalePrice`, else 0. Check `.value_counts()` — what's the baseline accuracy if a model always guesses the majority class?**

# %%
# Write your code here

# %% [markdown]
# **Q5.2 Build `x` using these columns: `OverallQual`, `TotalSF`, `HouseAge`, `TotalBath`, `GarageCars`, `BedroomAbvGr`, `MSZoning`, `Neighborhood`, `KitchenQual`. Build `y` as the `Expensive` column.**

# %%
# Write your code here

# %% [markdown]
# **Q5.3 Split `x` and `y` into `x_train`, `x_test`, `y_train`, `y_test` using `train_test_split` with `test_size=0.2` and `random_state=42`. Print the shape of all four.**

# %%
# Write your code here

# %% [markdown]
# # 🔤 **6. Encoding Categorical Features**
#
# ### _`OneHotEncoder` → turns text categories into 0/1 columns. Always fit on `x_train` only, then transform both train and test._
#
# ---

# %% [markdown]
# **Q6.1 From the columns you picked in Q5.2, identify which ones are categorical (text/`object` dtype) and which are numeric. List both groups.**

# %%
# Write your code here

# %% [markdown]
# **Q6.2 Use `OneHotEncoder` (with `handle_unknown='ignore'`) on the categorical columns — `MSZoning`, `Neighborhood`, `KitchenQual`. Fit it only on `x_train`, then use `.transform()` on both `x_train` and `x_test`.**

# %%
# Write your code here

# %% [markdown]
# **Q6.3 Combine the one-hot encoded categorical columns with the numeric columns (`OverallQual`, `TotalSF`, `HouseAge`, `TotalBath`, `GarageCars`, `BedroomAbvGr`) into a single array for train, and a single array for test.**

# %%
# Write your code here

# %% [markdown]
# # 📏 **7. Scaling Numeric Features**
#
# ### _`StandardScaler` → puts numeric columns on the same scale. Important because KNN is entirely distance-based — a column like `TotalSF` (in the thousands) shouldn't drown out a column like `OverallQual` (1–10)._
#
# ---

# %% [markdown]
# **Q7.1 Use `StandardScaler` on just the numeric columns from Q6.3. Fit it only on `x_train`'s numeric columns, then transform both `x_train` and `x_test`.**

# %%
# Write your code here

# %% [markdown]
# **Q7.2 Combine the scaled numeric columns with the one-hot encoded categorical columns to get your final `x_train_final` and `x_test_final` arrays, ready for the model.**

# %%
# Write your code here

# %% [markdown]
# # 🤖 **8. KNN — Build, Train, Predict & Evaluate**
#
# ### _`.fit()` → learn from training data | `.predict()` → predict on new data | `accuracy_score`, `confusion_matrix`, `classification_report` → measure performance_
#
# ---

# %% [markdown]
# **Q8.1 Import `KNeighborsClassifier` from `sklearn.neighbors`. Create a model with `k=5` and train it (`.fit()`) on `x_train_final` and `y_train`.**

# %%
# Write your code here

# %% [markdown]
# **Q8.2 Use the trained model to predict on `x_test_final`. Print the first 10 predictions next to the first 10 actual values from `y_test` to eyeball how it did.**

# %%
# Write your code here

# %% [markdown]
# **Q8.3 Import `accuracy_score` from `sklearn.metrics` and compute the test accuracy. Is it better than the baseline you calculated in Q5.1?**

# %%
# Write your code here

# %% [markdown]
# **Q8.4 Import `confusion_matrix` from `sklearn.metrics` and print it for your predictions. How many houses were correctly vs incorrectly classified as "Expensive"?**

# %%
# Write your code here

# %% [markdown]
# **Q8.5 Import `classification_report` from `sklearn.metrics` and print it. Compare the precision and recall for class 0 (not expensive) vs class 1 (expensive).**

# %%
# Write your code here

# %% [markdown]
# **Q8.6 KNN's performance depends heavily on `k`. Write a loop that trains a `KNeighborsClassifier` for every `k` from 1 to 20, and stores the test accuracy for each value of `k` in a list.**

# %%
# Write your code here

# %% [markdown]
# **Q8.7 Find and print which value of `k` gave the highest test accuracy in Q8.6. (Optional: plot `k` vs accuracy using `matplotlib` to visualize the trend.)**

# %%
# Write your code here
