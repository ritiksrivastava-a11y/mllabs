# %% [markdown]
# # 🤖 **Machine Learning Practice 1**
#
# ### _Covers Lecture 15 (Introduction to Machine Learning), Lecture 16 (EDA and Encoding), and Lecture 17 (Types of Encoding and First Model)._
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# # 🔄 **1. Traditional Programming vs Machine Learning**
#
# ### _In traditional programming, a human writes explicit rules to turn input into output. In Machine Learning, the algorithm learns the rules itself from examples (data + expected output)._
#
# ---

# %% [markdown]
# #### **Q1.1 In your own words, explain the difference between Traditional Programming and Machine Learning. Give one real-world example of each.**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q1.2 Why is Machine Learning better suited than traditional programming for a task like spam email detection?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 🧭 **2. Two Ways to Learn from Data — Supervised vs Unsupervised**
#
# ### _Supervised Learning trains on labeled data (input + correct output is known). Unsupervised Learning finds patterns in data that has no labels._
#
# ---

# %% [markdown]
# #### **Q2.1 Explain the difference between Supervised and Unsupervised Learning. What role does a 'label' play in this distinction?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q2.2 Classify each of the following as Supervised or Unsupervised, with a one-line reason:
# (a) Grouping customers into segments based on purchase behavior
# (b) Predicting house prices based on features
# (c) Detecting unusual patterns in credit card transactions without any labeled fraud data**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 📈 **3. Regression and Classification**
#
# ### _Both are types of Supervised Learning. Regression predicts a continuous number (e.g. price, temperature). Classification predicts a category/class (e.g. yes/no, spam/not-spam)._
#
# ---

# %% [markdown]
# #### **Q3.1 What is the difference between Regression and Classification? Give one example problem for each.**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q3.2 Is predicting whether a Titanic passenger survived (0 or 1) a Regression or a Classification problem? Justify your answer.**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 🗺️ **4. The ML Pipeline (Theory)**
#
# ### _A Machine Learning pipeline is the sequence of steps taken from raw data to a working, evaluated model._
#
# ---

# %% [markdown]
# #### **Q4.1 List the standard steps of a Machine Learning pipeline in order, from raw data to a trained, evaluated model.**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q4.2 Why do we split data into Training and Testing sets instead of using the entire dataset for both training and evaluation?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 💻 **5. The ML Pipeline (Coding)**
#
# ### _Before building any model, we set up our environment and take a first look at the raw data we'll be working with._
#
# ---

# %% [markdown]
# #### **Q5.1 Import the libraries you will need for a basic ML pipeline: `pandas`, `numpy`, and `train_test_split` from `sklearn.model_selection`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q5.2 Print `df.shape` and `df.info()` to understand the size of the dataset and which columns you're working with, before building a pipeline.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧰 **6. scikit-learn Basics**
#
# ### _scikit-learn (`sklearn`) is the main Python library used to build ML models. Almost every model in sklearn follows the same pattern: `.fit()` to train, `.predict()` to make predictions._
#
# ---

# %% [markdown]
# #### **Q6.1 What is scikit-learn used for in a Machine Learning pipeline? Import it and print its version using `sklearn.__version__`.**
#
# ---

# %%
import sklearn

# Write your code here

# %% [markdown]
# #### **Q6.2 In your own words, explain what `.fit()` and `.predict()` do when called on a scikit-learn model. You don't need to write model code yet — just explain the two methods.**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 🧹 **7. Data Cleaning**
#
# ### _Real-world data almost always has missing or unusable values — these must be handled before a model can be trained on the data._
#
# ---

# %% [markdown]
# #### **Q7.1 Check `df` for missing values in every column using `.isnull().sum()`. Which columns have missing data?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q7.2 Drop the `Cabin` column entirely (too many missing values to be useful), fill missing `Age` values with the median age, and drop the rows where `Embarked` is missing. Save the result as `df_clean`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🎯 **8. Features and Target**
#
# ### _The Target (or label) is the column you want to predict. The Features are the columns used as input to make that prediction._
#
# ---

# %% [markdown]
# #### **Q8.1 In this Titanic survival prediction problem, which column is the Target and which columns could be Features? Why can't `PassengerId`, `Name`, or `Ticket` be used as features directly?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q8.2 From `df_clean`, create `X` (features) using the columns `Pclass`, `Sex`, `Age`, `Fare`, `Embarked`, and create `y` (target) using the `Survived` column.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # ✂️ **9. Train/Test/Split**
#
# ### _`train_test_split()` divides your data into a portion used for training the model and a portion kept aside to test how well it performs on unseen data._
#
# ---

# %% [markdown]
# #### **Q9.1 Split `X` and `y` into `X_train`, `X_test`, `y_train`, `y_test` using `train_test_split()`, with 80% for training and 20% for testing, and `random_state=42`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q9.2 What does setting `random_state=42` do, and why is it good practice to set it when splitting data?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 🔤 **10. Encoding**
#
# ### _Machine Learning models can only work with numbers, not text. Encoding converts categorical (text) columns into numeric form. Label Encoding assigns each category a number; One-Hot Encoding creates a separate 0/1 column for each category._
#
# ---

# %% [markdown]
# #### **Q10.1 What is the difference between Label Encoding and One-Hot Encoding? When would you prefer one over the other?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# #### **Q10.2 In `X_train` and `X_test`, encode the `Sex` column using Label Encoding (e.g. `male` = 0, `female` = 1).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q10.3 Encode the `Embarked` column using One-Hot Encoding with `pd.get_dummies()`. Apply it consistently to both `X_train` and `X_test` so they end up with the same columns.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧮 **11. KNN — First Model**
#
# ### _K-Nearest Neighbors (KNN) is one of the simplest classification algorithms. It predicts a new point's class by looking at the 'K' closest points in the training data and taking a majority vote._
#
# ---

# %% [markdown]
# #### **Q11.1 Import `KNeighborsClassifier` from `sklearn.neighbors`, create a model with `n_neighbors=5`, and train it using `.fit(X_train, y_train)`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q11.2 Use the trained model to predict on `X_test` using `.predict()`, then check the accuracy using `accuracy_score()` from `sklearn.metrics`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **Q11.3 In your own words, explain how KNN makes a prediction for a new data point. What does the `n_neighbors` (K) value control?**
#
# ---

# %% [markdown]
# _Write your answer here._

# %% [markdown]
# # 🔥 **12. Challenge Questions**
#
# ### _These combine everything from this notebook — cleaning, encoding, splitting, and training — into a single end-to-end workflow._
#
# ---

# %% [markdown]
# #### **C1. Starting from the raw `df`, write a single end-to-end pipeline in one cell: clean the data, build `X` and `y`, encode categorical columns, split into train/test, train a KNN model, and print the final accuracy.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **C2. Try `n_neighbors = 3`, `7`, and `11` for your KNN model. Print the accuracy for each value. Which value gives the best accuracy on your test split?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# #### **C3. From `df_clean`, keep only passengers older than 12 years (to exclude young children). Rebuild the entire pipeline — features, split, encoding, training — using only this subset, and compare its accuracy to your full-dataset model from C1.**
#
# ---

# %%
# Write your code here
