# %% [markdown]
# # 🐼 **Pandas Practice 2 — New Topics Only**
#
# ### _Covers everything from your notes that Practice 1 didn't touch: DataFrame/Series creation, `.sample()`, conditional assignment, the Titanic dataset, `.dropna()`, first/last & size/count in GroupBy, named aggregations, pivot tables, filtering groups, and common indexing mistakes._
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this first. We'll keep using the `mpg` dataset from Practice 1, and you'll load the **Titanic** dataset yourself in Section 5 (URL given there)._
#
# ---

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/skm22/Introduction_To_Machine_Learning/main/Data/mpg.csv"
df = pd.read_csv(url)
df.head()

# %% [markdown]
# # 🏗️ **1. Creating DataFrames from Dict & Column Data Types**
#
# ### _`pd.DataFrame(dict)` → build a DataFrame from a dictionary of lists | `.dtypes` → check each column's data type | `.astype()` → convert a column's data type_
#
# ---

# %% [markdown]
# **Q1.1 Create a DataFrame called `students` from a dictionary with columns `name` (5 student names), `age` (integers), and `marks` (floats). Print the DataFrame and check the dtype of every column using `.dtypes`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q1.2 In `students`, convert the `age` column to `float` and the `marks` column to `int` using `.astype()`. Print `.dtypes` again to confirm the change.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧵 **2. Standalone Series, Custom Indexing & .values**
#
# ### _`pd.Series(data)` → create a standalone Series | `pd.Series(data, index=[...])` → give it custom index labels | `.values` → get the underlying data as a plain NumPy array_
#
# ---

# %% [markdown]
# **Q2.1 Create a standalone Series called `city_temp` holding the temperature of 5 cities of your choice, using the city names as a custom index, e.g. `index=['Delhi','Mumbai',...]`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q2.2 From `city_temp`, print the value for one city using its label (e.g. `city_temp['Delhi']`), then print the whole Series as a NumPy array using `.values`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 👀 **3. .sample() for Data Preview**
#
# ### _`.sample(n)` → randomly pick n rows | `.sample(frac=x)` → randomly pick a fraction of the rows | gives an unbiased peek at the data, unlike `.head()` which always shows the same rows_
#
# ---

# %% [markdown]
# **Q3.1 Use `.sample(5)` on `df` to view 5 random rows. Run the cell a couple of times and confirm the rows change each time.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q3.2 Use `.sample(frac=0.1, random_state=1)` to select 10% of the rows from `df`, and print how many rows got selected.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🎯 **4. Conditional Column Assignment**
#
# ### _`df.loc[condition, 'col'] = value` → assign a value only to rows that meet a condition | `np.where(condition, a, b)` → vectorized if-else, faster than `.apply()` with a lambda_
#
# ---

# %% [markdown]
# **Q4.1 Using `.loc[]`, create a new column `power_type` and set it to `'High'` where `horsepower > 100` and `'Low'` everywhere else — do this with two separate `.loc[]` assignment lines.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q4.2 Recreate the same idea as a new column `power_type_v2`, but this time in a single line using `np.where()` instead of `.loc[]`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🚢 **5. Titanic Dataset & Multi-Condition Queries**
#
# ### _Load a new dataset with `pd.read_csv()`, inspect its schema with `.info()`, then combine multiple conditions with `&`, `|`, `~` — same techniques, new data._
#
# ### _Titanic dataset URL: `https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv`_
#
# ---

# %% [markdown]
# **Q5.1 Load the Titanic dataset into a DataFrame called `titanic`. Use `.info()` and `.head()` to understand its columns and data types.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q5.2 Filter `titanic` for female passengers (`Sex == 'female'`) who survived (`Survived == 1`) and were traveling in 1st class (`Pclass == 1`). How many such passengers are there?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q5.3 Filter `titanic` for passengers who are NOT in 3rd class using `~`, and whose `Age` is missing (`.isnull()`).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧽 **6. Removing Missing Values with .dropna()**
#
# ### _`.dropna()` → drop rows with any missing value | `.dropna(subset=[...])` → drop rows only when specific columns are missing | `.dropna(axis=1)` → drop columns instead of rows_
#
# ---

# %% [markdown]
# **Q6.1 Check how many rows in `titanic` have a missing `Age`, then create `titanic_clean` by dropping only those rows using `.dropna(subset=['Age'])`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q6.2 Compare the `.shape` of `titanic` before and after plain `.dropna()` (which drops a row if ANY column has a missing value). What's the difference, and why?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧮 **7. GroupBy: First/Last Values & size() vs count()**
#
# ### _`.first()` / `.last()` → first/last row's value in each group | `.size()` → rows per group (includes NaNs) | `.count()` → non-null values per group, per column_
#
# ---

# %% [markdown]
# **Q7.1 Group `df` by `origin` and use `.first()` and `.last()` to see the first and last car listed for each origin.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q7.2 Group `df` by `cylinders` and compare `.size()` vs `.count()`. Are the numbers the same for every column? Why might they differ if a column has missing values?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q7.3 Group `titanic` by `Pclass` and use `.size()` to count passengers per class, then use `.count()` on just the `Age` column to see how many passengers per class have a known age.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🏷️ **8. Named Aggregations with agg()**
#
# ### _`.agg(new_col=('source_col', 'func'))` → give custom, readable names to aggregated columns instead of the default multi-level column names_
#
# ---

# %% [markdown]
# **Q8.1 Group `df` by `origin` and use named aggregation to build a summary with columns `avg_mpg` (mean of mpg) and `max_hp` (max of horsepower).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q8.2 Group `titanic` by `Pclass` and `Sex` together, and use named aggregation to create `avg_age` (mean of Age) and `total_passengers` (count of PassengerId).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 📋 **9. Creating a Summary Table (pivot_table)**
#
# ### _`pd.pivot_table(df, values=, index=, columns=, aggfunc=)` → reshape data into a spreadsheet-style summary table_
#
# ---

# %% [markdown]
# **Q9.1 Create a pivot table from `df` showing average `mpg`, with `origin` as rows and `cylinders` as columns.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q9.2 Create a pivot table from `titanic` showing the survival rate (mean of `Survived`), with `Pclass` as rows and `Sex` as columns.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔍 **10. Filtering Groups**
#
# ### _`.groupby('col').filter(func)` → keep only the groups for which a condition on the WHOLE group is True — different from row-wise filtering_
#
# ---

# %% [markdown]
# **Q10.1 Group `df` by `cylinders` and keep only the groups that have more than 20 cars, using `.groupby().filter()`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q10.2 Group `titanic` by `Pclass` and keep only the groups where the average `Fare` is greater than 20.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🐞 **11. Common Indexing Syntax Errors (Debug It)**
#
# ### _These snippets look almost right but throw an error or give a wrong result. Spot the mistake, explain it in a comment, and write the corrected line._
#
# ---

# %% [markdown]
# **Q11.1 This line is meant to select the `mpg` and `weight` columns together but throws an error. Find the bug and fix it:**
# ```python
# df['mpg', 'weight']
# ```
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q11.2 This line is meant to select rows 2 to 5 using `.iloc` but only returns 3 rows instead of 4. Explain why, and write the version that actually returns 4 rows:**
# ```python
# df.iloc[2:5]
# ```
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔥 **Challenge Round**
#
# ### _These mix several concepts from Practice 1 and Practice 2 together. Take your time._
#
# ---

# %% [markdown]
# **C1. Using `df`, build a summary table (via `pivot_table` or `groupby` + named `agg()`) showing, for each `origin`: average `mpg`, average `horsepower`, and total number of cars — sorted from highest to lowest average `mpg`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **C2. On `titanic`: drop rows with a missing `Age`, create a new column `age_group` using conditional assignment (`'Child'` if `Age < 18` else `'Adult'`), then group by `Pclass` and `age_group` to find the survival rate for each combination.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **C3. Create a DataFrame from a dictionary representing 6 products with columns `product`, `price`, and `category`. Using `.groupby('category').filter()`, keep only the categories whose total (`sum`) price is above a threshold of your choice. Then build a pivot table showing the average `price` per `category`.**
#
# ---

# %%
# Write your code here
