# %% [markdown]
# # Pandas + Seaborn Practice - bike_resale.csv
#
# A website sells used bikes. The owner needs answers from the listings.
#
# Solve each question in the empty cell below it.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('bike_resale.csv')
df.head()

# %% [markdown]
# ---
# ## Selecting data

# %% [markdown]
# ### Question 1
#
# The website owner wants a short list. Show only the `brand`, `km_driven` and `price_thousand` of the first 10 bikes.

# %% [markdown]
# ### Question 2
#
# A customer only wants a Royal Enfield. Show all Royal Enfield bikes. How many are there?

# %% [markdown]
# ### Question 3
#
# Another customer wants a bike in **Excellent** condition that costs **less than 30 thousand**. Show only the `brand`, `condition` and `price_thousand` of such bikes.

# %% [markdown]
# ---
# ## Cleaning data

# %% [markdown]
# ### Question 4
#
# Before sharing the file, the owner wants to know which columns have blank values and how many. Also check for repeated rows.

# %% [markdown]
# ### Question 5
#
# Fill the blanks in `mileage_kmpl` with the average mileage. Remove the rows where `km_driven` is blank. Print the shape after both steps.

# %% [markdown]
# ---
# ## Grouping data

# %% [markdown]
# ### Question 6
#
# Which brand sells for the most on average? Find the average price of each brand, from highest to lowest.

# %% [markdown]
# ### Question 7
#
# For each condition, show the average price **and** the number of bikes in one table.

# %% [markdown]
# ---
# ## Plotting

# %% [markdown]
# ### Question 8
#
# How far have most bikes been driven? Draw the distribution of `km_driven`.

# %% [markdown]
# ### Question 9
#
# For every brand, show how many bikes were sold in the first week and how many were not.

# %% [markdown]
# ### Question 10
#
# A buyer says condition does not change the price. Draw one plot of `price_thousand` for each `condition` and check if the buyer is right.

# %% [markdown]
# ### Question 11
#
# Draw `age_months` against `price_thousand`, coloured by `sold_in_week`. What happens to price as a bike gets older?

# %% [markdown]
# ### Question 12
#
# Draw a heatmap of the numeric columns. Which two columns move together the most?
