# %% [markdown]
# # 📊 **EDA + Matplotlib & Seaborn Practice**
#
# ---

# %% [markdown]
# # ⚙️ **0. Setup**
#
# ### _Run this cell first — it loads the dataset used throughout the notebook._
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Classic restaurant tips dataset (built into seaborn) — small, clean, easy to reason about
df = sns.load_dataset("tips")
df.head()

# %% [markdown]
# # 🖊️ **1. Matplotlib Basics — Quick Intro**
#
# ### _`plt.plot()` → line plot | `plt.figure(figsize=)` → set plot size | `.title()/.xlabel()/.ylabel()` → labels | `plt.legend()` → label multiple lines | `plt.show()` → display the plot_
#
# ---

# %% [markdown]
# **Q1.1 Plot a simple line using `plt.plot([1,2,3,4,5], [10,20,15,25,30])`. Add a title `'My First Plot'`, and label the x-axis `'X'` and y-axis `'Y'`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q1.2 Set the figure size to `(8,4)` using `plt.figure(figsize=(8,4))`, then plot two lines on the same axes — `y1=[1,4,9,16,25]` and `y2=[1,2,3,4,5]` — each with its own `label=`, and show a legend with `plt.legend()`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q1.3 Plot a simple bar chart using `plt.bar(['A','B','C'], [5,7,3])`. Give it a title and axis labels.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔍 **2. Basic Exploration**
#
# ### _`.head(n)` / `.tail(n)` → first/last rows | `.shape`, `.columns`, `.dtypes` | `.info()` / `.describe()` → summary stats_
#
# ---

# %% [markdown]
# **Q2.1 Display the first 6 rows and the last 4 rows of `df`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q2.2 Print the shape of `df`, the column names, and the dtype of each column.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q2.3 Use `.info()` and `.describe()`. Also run `.describe(include='object')` — what does it show for categorical columns?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q2.4 Check how many missing values exist in each column using `.isnull().sum()`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 📈 **3. Univariate Numeric Plots — Matplotlib**
#
# ### _`plt.hist()` → distribution | `plt.boxplot()` → spread & outliers | `plt.subplots(nrows, ncols)` → multiple plots in one figure_
#
# ---

# %% [markdown]
# **Q3.1 Plot a histogram of `total_bill` using `plt.hist()` with 20 bins. Add a title and x/y labels.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q3.2 Plot a boxplot of `tip` using `plt.boxplot()`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q3.3 Using `plt.subplots(1, 3, figsize=(15,4))`, plot histograms of `total_bill`, `tip`, and `size` side by side in one figure.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 📉 **4. Univariate Numeric Plots — Seaborn**
#
# ### _`sns.histplot(kde=True)` → histogram + density curve | `sns.boxplot()` | `sns.violinplot()` → distribution shape + quartiles combined_
#
# ---

# %% [markdown]
# **Q4.1 Plot `sns.histplot()` of `total_bill` with `kde=True`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q4.2 Plot `sns.boxplot()` of `tip`. How does it compare visually to the matplotlib version in Q3.2?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q4.3 Plot `sns.violinplot()` of `total_bill`. What does the violin shape tell you that a boxplot alone doesn't?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧮 **5. Univariate Categorical Plots**
#
# ### _`.value_counts().plot(kind='bar')` → matplotlib bar chart | `plt.pie()` → proportions | `sns.countplot()` → seaborn's built-in count bar chart_
#
# ---

# %% [markdown]
# **Q5.1 Use `.value_counts()` on `day` and plot it as a bar chart with `.plot(kind='bar')`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q5.2 Plot a pie chart of `time` (Lunch vs Dinner) proportions using `plt.pie()`, with `autopct='%1.1f%%'` to show percentages.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q5.3 Use `sns.countplot(x='smoker', data=df)` to show how many smokers vs non-smokers there are.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🔗 **6. Bivariate — Numeric vs Numeric**
#
# ### _`plt.scatter()` | `sns.scatterplot(hue=...)` → color points by a category | `sns.regplot()` → scatter + fitted regression line_
#
# ---

# %% [markdown]
# **Q6.1 Use `plt.scatter()` to plot `total_bill` (x) vs `tip` (y).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q6.2 Recreate the same scatter plot with `sns.scatterplot()`, colored by `time` using `hue`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q6.3 Use `sns.regplot(x='total_bill', y='tip', data=df)` to see the fitted trend line. Does tip increase roughly linearly with the bill?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🎻 **7. Bivariate — Numeric vs Categorical**
#
# ### _`sns.boxplot(x=cat, y=num)` | `sns.violinplot()` | `sns.barplot()` → mean + confidence interval per category | `sns.stripplot()` / `sns.swarmplot()` → individual points_
#
# ---

# %% [markdown]
# **Q7.1 Use `sns.boxplot()` to compare `total_bill` across each `day`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q7.2 Use `sns.violinplot()` to compare `tip` across `sex`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q7.3 Use `sns.barplot(x='day', y='total_bill', data=df)` to show the average bill per day (note the error bars).**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q7.4 Use `sns.stripplot()` or `sns.swarmplot()` to show individual `tip` values split by `smoker`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🗂️ **8. Categorical vs Categorical**
#
# ### _`pd.crosstab()` → cross-tabulated counts | `sns.heatmap()` on a crosstab → visualize the counts as a grid | `sns.countplot(hue=...)` → grouped bars_
#
# ---

# %% [markdown]
# **Q8.1 Create a `pd.crosstab(df['day'], df['time'])` and visualize it with `sns.heatmap(annot=True, fmt='d')`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q8.2 Use `sns.countplot(x='day', hue='sex', data=df)` to show grouped bars of male vs female counts per day.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🌡️ **9. Correlation & Pairwise Relationships**
#
# ### _`.corr()` → correlation matrix of numeric columns | `sns.heatmap()` → visualize correlations | `sns.pairplot()` → scatter matrix of every numeric pair_
#
# ---

# %% [markdown]
# **Q9.1 Compute the correlation matrix of `total_bill`, `tip`, and `size` using `.corr(numeric_only=True)`, then visualize it with `sns.heatmap(annot=True, cmap='coolwarm')`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q9.2 Use `sns.pairplot(df, vars=['total_bill','tip','size'], hue='smoker')`. Which pair looks most strongly correlated?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 📅 **10. Trends Across Categories**
#
# ### _`.groupby()` + `sns.barplot()` / `sns.pointplot()` → compare a metric across an ordered category (e.g. day of the week)_
#
# ---

# %% [markdown]
# **Q10.1 Group by `day` and find the average `tip`. Plot it as a bar chart using `.plot(kind='bar')`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q10.2 Use `sns.pointplot(x='day', y='total_bill', data=df, order=['Thur','Fri','Sat','Sun'])` to see the trend of average bill across the week as connected points.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🚨 **11. Outlier Detection**
#
# ### _IQR method: `Q1 = col.quantile(0.25)`, `Q3 = col.quantile(0.75)`, `IQR = Q3-Q1` → outliers lie outside `[Q1-1.5*IQR, Q3+1.5*IQR]` | boxplots make outliers visible directly_
#
# ---

# %% [markdown]
# **Q11.1 Use the IQR method to detect outliers in the `total_bill` column. How many rows are flagged as outliers?**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q11.2 Create a filtered DataFrame with those outliers removed. Using `plt.subplots(1,2)`, show `sns.boxplot()` of `total_bill` before and after removal, side by side.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🎨 **12. Customizing Matplotlib Plots**
#
# ### _`figsize`, `title`, `xlabel`/`ylabel`, `legend()` | `plt.style.use()` | `ax.annotate()` → point out a specific value | `plt.savefig()` → export a figure_
#
# ---

# %% [markdown]
# **Q12.1 Create a figure with `plt.subplots(1, 2, figsize=(12,5))`: on the left plot a histogram of `total_bill`, on the right a scatter of `total_bill` vs `tip`. Give each subplot its own title and axis labels.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q12.2 Apply `plt.style.use('ggplot')` (or another built-in style) and redraw one of your earlier plots. Use `ax.annotate()` to label the point with the maximum `tip`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q12.3 Save one of your figures to disk as `my_plot.png` using `plt.savefig()` with `dpi=150`.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🖌️ **13. Seaborn Styling & Themes**
#
# ### _`sns.set_style()` → background grid style | `sns.set_palette()` → color palette | `sns.despine()` → remove top/right borders | `sns.set_context()` → scale for poster/talk/notebook_
#
# ---

# %% [markdown]
# **Q13.1 Call `sns.set_style('whitegrid')` and `sns.set_palette('viridis')`, then redraw the `sns.boxplot()` of `total_bill` by `day` from Q7.1.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q13.2 Apply `sns.despine()` to remove the top and right spines from one of your plots, and try `sns.set_context('talk')` to see how the scaling changes.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🧩 **14. Multi-Panel / Facet Plots**
#
# ### _`sns.FacetGrid` → grid of plots split by a categorical column | `sns.catplot()` → categorical plot with automatic faceting via `col=`/`row=` | `sns.relplot()` → relational plot (scatter/line) with faceting_
#
# ---

# %% [markdown]
# **Q14.1 Use `sns.FacetGrid(df, col='time')` and `.map(sns.histplot, 'total_bill')` to show a separate bill histogram for Lunch vs Dinner.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q14.2 Use `sns.catplot(x='day', y='total_bill', kind='box', col='sex', data=df)` to compare bill-by-day across male and female.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# **Q14.3 Use `sns.relplot(x='total_bill', y='tip', hue='smoker', col='time', data=df)` for a faceted scatter plot.**
#
# ---

# %%
# Write your code here

# %% [markdown]
# # 🏁 **15. Mini EDA Dashboard**
#
# ### _Combine everything: use `plt.subplots(nrows, ncols)` and pass each `ax` into a seaborn function's `ax=` parameter to build a single-figure dashboard._
#
# ---

# %% [markdown]
# **Q15.1 Build a 2×3 dashboard with `plt.subplots(2, 3, figsize=(18,10))` containing: (1) histogram of `total_bill`, (2) boxplot of `total_bill` by `day`, (3) countplot of `smoker`, (4) scatter of `total_bill` vs `tip` colored by `time`, (5) correlation heatmap of `total_bill`/`tip`/`size`, (6) bar chart of average `tip` by `day`. Give the whole figure a `plt.suptitle()`.**
#
# ---

# %%
# Write your code here
